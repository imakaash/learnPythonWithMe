# %% [markdown]
# Documentation of pandas:
#
# "https://pandas.pydata.org/pandas-docs/stable/reference/frame.html"

# %% [markdown]
# # Transforming Data

# %% [markdown]
# ### Inspecting a DataFrame
#
# When you get a new DataFrame to work with, the first thing you need to do is explore it and see what it contains. There are several useful methods and attributes for this.
#
# * .head() returns the first few rows (the “head” of the DataFrame).
# * .info() shows information on each of the columns, such as the data type and number of missing values.
# * .shape returns the number of rows and columns of the DataFrame.
# * .describe() calculates a few summary statistics for each column.

# %%
import pandas as pd
df = pd.read_csv('adult.csv')
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
# age                48842 non-null int64
# workclass          48842 non-null object
# fnlwgt             48842 non-null int64
# education          48842 non-null object
# educational-num    48842 non-null int64
# marital-status     48842 non-null object
# occupation         48842 non-null object
# relationship       48842 non-null object
# race               48842 non-null object
# gender             48842 non-null object
# capital-gain       48842 non-null int64
# capital-loss       48842 non-null int64
# hours-per-week     48842 non-null int64
# native-country     48842 non-null object
# income             48842 non-null object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.describe()['fnlwgt'].astype('int64')
# Out:
# count      48842
# mean      189664
# std       105604
# min        12285
# 25%       117550
# 50%       178144
# 75%       237642
# max      1490400
# Name: fnlwgt, dtype: int64

# %% [markdown]
# ### Parts of a DataFrame
# To better understand DataFrame objects, it's useful to know that they consist of three components, stored as attributes:
#
# * .values: A two-dimensional NumPy array of values.
# * .columns: An index of columns: the column names.
# * .index: An index for the rows: either row numbers or row names.

# %%
array = df.values
array
# Out:
# array([[25, 'Private', 226802, ..., 40, 'United-States', '<=50K'],
#        [38, 'Private', 89814, ..., 50, 'United-States', '<=50K'],
#        [28, 'Local-gov', 336951, ..., 40, 'United-States', '>50K'],
#        ...,
#        [58, 'Private', 151910, ..., 40, 'United-States', '<=50K'],
#        [22, 'Private', 201490, ..., 20, 'United-States', '<=50K'],
#        [52, 'Self-emp-inc', 287927, ..., 40, 'United-States', '>50K']],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=48842, step=1)

# %% [markdown]
# ### Sorting rows
# Finding interesting bits of data in a DataFrame is often easier if you change the order of the rows. You can sort the rows by passing a column name to .sort_values().
#
# In cases where rows have the same value (this is common if you sort on a categorical variable), you may wish to break the ties by sorting on another column. You can sort on multiple columns in this way by passing a list of column names.
#
#   Sort on …	        Syntax
# * one column	    df.sort_values("col1")
# * multiple columns	df.sort_values(["col1","col2"])
#
# By combining .sort_values() with .head(), you can answer questions in the form, "What are the top cases where…?".

# %%
 df.sort_values(["hours-per-week","age"], ascending=False).head()
# Out:
#        age         workclass  fnlwgt education  educational-num  \
# 8427    90       Federal-gov  311184   Masters               14
# 31637   90           Private   90523   HS-grad                9
# 8677    73  Self-emp-not-inc  228899   7th-8th                4
# 32885   73  Self-emp-not-inc  102510   7th-8th                4
# 36278   72           Private  268861   7th-8th                4
#
#            marital-status        occupation   relationship   race  gender  \
# 8427             Divorced    Prof-specialty  Not-in-family  White    Male
# 31637             Widowed  Transport-moving      Unmarried  White    Male
# 8677        Never-married      Adm-clerical  Not-in-family  White  Female
# 32885  Married-civ-spouse   Farming-fishing        Husband  White    Male
# 36278             Widowed     Other-service  Not-in-family  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 8427              0             0              99  United-States  <=50K
# 31637             0             0              99  United-States  <=50K
# 8677              0             0              99  United-States  <=50K
# 32885          6418             0              99  United-States   >50K
# 36278             0             0              99              ?  <=50K

# %% [markdown]
# ### Subsetting columns
# When working with data, you may not need all of the variables in your dataset. Square-brackets ([]) can be used to select only the columns that matter to you in an order that makes sense to you.
#
# * To select only "col_a" of the DataFrame df, use
# df["col_a"]
#
# * To select "col_a" and "col_b" of df, use
# df[["col_a", "col_b"]]

# %%
df[["age","occupation","relationship"]].head(n=10)
# Out:
#    age         occupation   relationship
# 0   25  Machine-op-inspct      Own-child
# 1   38    Farming-fishing        Husband
# 2   28    Protective-serv        Husband
# 3   44  Machine-op-inspct        Husband
# 4   18                  ?      Own-child
# 5   34      Other-service  Not-in-family
# 6   29                  ?      Unmarried
# 7   63     Prof-specialty        Husband
# 8   24      Other-service      Unmarried
# 9   55       Craft-repair        Husband

# %% [markdown]
# A large part of data science is about finding which bits of your dataset are interesting. One of the simplest techniques for this is to find a subset of rows that match some criteria. This is sometimes known as filtering rows or selecting rows.
#
# There are many ways to subset a DataFrame, perhaps the most common is to use relational operators to return True or False for each row, then pass that inside square brackets.
# * dogs[dogs["height_cm"] > 60]
# * dogs[dogs["color"] == "tan"]
#
# You can filter for multiple conditions at once by using the "logical and" operator, &.
# * dogs[(dogs["height_cm"] > 60) & (dogs["col_b"] == "tan")]

# %%
df[(df["hours-per-week"]> 90) & (df["age"]>70)]
# Out:
#        age         workclass  fnlwgt education  educational-num  \
# 8427    90       Federal-gov  311184   Masters               14
# 8677    73  Self-emp-not-inc  228899   7th-8th                4
# 31637   90           Private   90523   HS-grad                9
# 32885   73  Self-emp-not-inc  102510   7th-8th                4
# 36278   72           Private  268861   7th-8th                4
#
#            marital-status        occupation   relationship   race  gender  \
# 8427             Divorced    Prof-specialty  Not-in-family  White    Male
# 8677        Never-married      Adm-clerical  Not-in-family  White  Female
# 31637             Widowed  Transport-moving      Unmarried  White    Male
# 32885  Married-civ-spouse   Farming-fishing        Husband  White    Male
# 36278             Widowed     Other-service  Not-in-family  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 8427              0             0              99  United-States  <=50K
# 8677              0             0              99  United-States  <=50K
# 31637             0             0              99  United-States  <=50K
# 32885          6418             0              99  United-States   >50K
# 36278             0             0              99              ?  <=50K

# %% [markdown]
# ### Subsetting rows by categorical variables
# Subsetting data based on a categorical variable often involves using the "or" operator (|) to select rows from multiple categories. This can get tedious when you want all states in one of three different regions,
#
# for example. Instead, use the .isin() method, which will allow you to tackle this problem by writing one condition instead of three separate ones.
#
# * colors = ["brown", "black", "tan"]
# * condition = dogs["color"].isin(colors)
# * dogs[condition]

# %%
print(df["occupation"].unique())
lst = ['Tech-support','Sales','Armed-Forces']
condition = df["occupation"].isin(lst)
df[condition]
# Out:
# ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' '?'
#  'Other-service' 'Prof-specialty' 'Craft-repair' 'Adm-clerical'
#  'Exec-managerial' 'Tech-support' 'Sales' 'Priv-house-serv'
#  'Transport-moving' 'Handlers-cleaners' 'Armed-Forces']
#        age         workclass  fnlwgt     education  educational-num  \
# 20      34           Private  107914     Bachelors               13
# 32      24  Self-emp-not-inc  188274     Bachelors               13
# 41      44      Self-emp-inc  120277     Assoc-voc               11
# 61      39           Private  118429  Some-college               10
# 69      43           Private  102606       HS-grad                9
# ...    ...               ...     ...           ...              ...
# 48810   29           Private  125976       HS-grad                9
# 48827   37           Private  198216    Assoc-acdm               12
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# 48837   27           Private  257302    Assoc-acdm               12
#
#            marital-status    occupation   relationship                race  \
# 20     Married-civ-spouse  Tech-support        Husband               White
# 32          Never-married         Sales  Not-in-family               White
# 41     Married-civ-spouse         Sales        Husband               White
# 61               Divorced         Sales  Not-in-family               White
# 69     Married-civ-spouse         Sales        Husband               White
# ...                   ...           ...            ...                 ...
# 48810           Separated         Sales      Unmarried               White
# 48827            Divorced  Tech-support  Not-in-family               White
# 48833  Married-civ-spouse         Sales        Husband               White
# 48834       Never-married  Tech-support  Not-in-family  Asian-Pac-Islander
# 48837  Married-civ-spouse  Tech-support           Wife               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 20       Male             0             0              47  United-States
# 32       Male             0             0              50  United-States
# 41       Male             0             0              45  United-States
# 61       Male             0             0              40  United-States
# 69       Male             0             0              48  United-States
# ...       ...           ...           ...             ...            ...
# 48810  Female             0             0              35  United-States
# 48827  Female             0             0              40  United-States
# 48833    Male             0             0              45  United-States
# 48834    Male             0             0              11         Taiwan
# 48837  Female             0             0              38  United-States
#
#       income
# 20      >50K
# 32     <=50K
# 41      >50K
# 61     <=50K
# 69     <=50K
# ...      ...
# 48810  <=50K
# 48827  <=50K
# 48833  <=50K
# 48834  <=50K
# 48837  <=50K
#
# [6965 rows x 15 columns]

# %% [markdown]
# ### Adding new columns
# You aren't stuck with just the data you are given. Instead, you can add new columns to a DataFrame. This has many names, such as transforming, mutating, and feature engineering.
#
# You can create new columns from scratch, but it is also common to derive them from other columns, for example, by adding columns together, or by changing their units.

# %%
df["hours-per-day"] = df["hours-per-week"]/5
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income  hours-per-day
# 0              40  United-States  <=50K            8.0
# 1              50  United-States  <=50K           10.0
# 2              40  United-States   >50K            8.0
# 3              40  United-States   >50K            8.0
# 4              30  United-States  <=50K            6.0

# %% [markdown]
# ### Operations
#
# There are lots of operations with pandas that will be really useful to you, but don't fall into any distinct category.

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
print(df['col2'].nunique())
print('--------------------------')
print(df['col2'].unique())
print('--------------------------')
print(df['col2'].value_counts())
# Out:
# 3
# --------------------------
# [444 555 666]
# --------------------------
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df['col1'].sum()
# Out:
# 10

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
# Applying functions using lambda
df['times2'] = df['col1'].apply(lambda x: x**2)
df.head()
# Out:
#    col1  col2 col3  times2
# 0     1   444  abc       1
# 1     2   555  def       4
# 2     3   666  ghi       9
# 3     4   444  xyz      16

# %%
# Check if column 'col3' starts with 'a'
df['col3'].apply(lambda x: 1 if x.startswith('a') else 0)
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# Name: col3, dtype: int64

# %%
df['original'] = df.apply(lambda rec: rec.times2/rec.col1, axis=1)
df.head()
# Out:
#    col1  col2 col3  times2  original
# 0     1   444  abc       1       1.0
# 1     2   555  def       4       2.0
# 2     3   666  ghi       9       3.0
# 3     4   444  xyz      16       4.0

# %% [markdown]
# # Aggregating Data

# %% [markdown]
# ### Mean and median
# Summary statistics are exactly what they sound like - they summarize many numbers in one statistic. For example, mean, median, minimum, maximum, and standard deviation are summary statistics. Calculating summary statistics allows you to get a better sense of your data, even if there's a lot of it.

# %%
df = pd.read_csv('adult.csv')
df['age'].describe()
# Out:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
print(df['age'].mean())
print(df['age'].median())
print('---------------------')
print(df['age'].describe().loc['mean'])
print(df['age'].describe()['50%'])
# Out:
# 38.64358543876172
# 37.0
# ---------------------
# 38.64358543876172
# 37.0

# %% [markdown]
# ### Summarizing dates
# Summary statistics can also be calculated on date columns which have values with the data type datetime64. Some summary statistics — like mean — don't make a ton of sense on dates, but others are super helpful, for example minimum and maximum, which allow you to see what time range your data covers.

# %%
time_df = pd.DataFrame({"Date":['7/3/2020','7/4/2020','7/5/2020','7/6/2020','7/7/2020']})
time_df["Date"] = pd.to_datetime(time_df["Date"], infer_datetime_format=True)
print(time_df["Date"].min())
print(time_df["Date"].max())
# Out:
# 2020-07-03 00:00:00
# 2020-07-07 00:00:00

# %% [markdown]
# ### Efficient summaries
# While pandas and NumPy have tons of functions, sometimes you may need a different function to summarize your data.
#
# The .agg() method allows you to apply your own custom functions to a DataFrame, as well as apply functions to more than one column of a DataFrame at once, making your aggregations super efficient.
#
# In the custom function for this exercise, "IQR" is short for inter-quartile range, which is the 75th percentile minus the 25th percentile. It's an alternative to standard deviation that is helpful if your data contains outliers.

# %%
# A custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)
    
# Print IQR of the age column
print(df['age'].agg(iqr))

print('---------------------')
print(df['age'].describe()['75%'] - df['age'].describe()['25%'])
# Out:
# 20.0
# ---------------------
# 20.0

# %% [markdown]
# ### Cumulative statistics
# Cumulative statistics can also be helpful in tracking summary statistics over time. In this exercise, you'll calculate the cumulative sum and cumulative max of a department's weekly sales, which will allow you to identify what the total sales were so far as well as what the highest weekly sales were so far.

# %%
# Sort df by age
sorted_df = df.sort_values('age')

# Get the cumulative sum of hours-per-week
sorted_df['cum_hours_per_week'] = sorted_df['hours-per-week'].cumsum()

# Get the cumulative max of hours_per_week
sorted_df['cum_max_hours_per_week'] = sorted_df['hours-per-week'].cummax()

# See the columns you calculated
print(sorted_df[["age", "hours-per-week", "cum_hours_per_week", "cum_max_hours_per_week"]].head())
# Out:
#        age  hours-per-week  cum_hours_per_week  cum_max_hours_per_week
# 32598   17              26                  26                      26
# 29817   17              35                  61                      35
# 36580   17              15                  76                      35
# 26409   17              12                  88                      35
# 19520   17              40                 128                      40

# %% [markdown]
# ### Dropping duplicates
# Removing duplicates is an essential skill to get accurate counts, because often you don't want to count the same thing multiple times.

# %%
"""
If you want to have the changes applied to the same dataframe, keep inplace=True. You don't need to assign it to a new variable.

df.drop_duplicates(subset="native-country", inplace=True)
"""

new_df = df.drop_duplicates(subset="native-country", inplace=False)
new_df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 19      40           Private   85019     Doctorate               16
# 23      25           Private  220931     Bachelors               13
# 37      22           Private  248446       5th-6th                3
# 46      39           Private  290208       7th-8th                4
# 74      46           Private  269034  Some-college               10
# 128     27  Self-emp-not-inc  115438       HS-grad                9
# 141     18           Private  262118  Some-college               10
# 220     34           Private  162312     Bachelors               13
# 232     55           Private  119751       Masters               14
# 237     42           Private  227968       HS-grad                9
# 296     30           Private  236543           9th                5
# 301     30           Private  169269          11th                7
# 309     51  Self-emp-not-inc  136708       HS-grad                9
# 377     24           Private  154835       HS-grad                9
# 385     47           Private  200808          11th                7
# 396     45           Private  355781     Bachelors               13
# 398     36           Private  116358       Masters               14
# 417     37         State-gov   67083  Some-college               10
# 473     39       Federal-gov  149347       Masters               14
# 498     34           Private  107960       5th-6th                3
# 544     45           Private  177536     Bachelors               13
# 586     36           Private  300333          11th                7
# 717     34                 ?  143582       HS-grad                9
# 794     49         Local-gov  126754       HS-grad                9
# 868     35       Federal-gov  207973     Doctorate               16
# 890     42           Private   67243       1st-4th                2
# 945     38           Private  216319     Doctorate               16
# 1030    23           Private  211345  Some-college               10
# 1126    48           Private  149640  Some-college               10
# 1161    38           Private  258339     Assoc-voc               11
# 1551    70           Private  118902     Bachelors               13
# 1748    52         Local-gov  192853       HS-grad                9
# 1907    47           Private  172155  Some-college               10
# 1911    51           Private  179479       HS-grad                9
# 2047    65           Private  444725   Prof-school               15
# 2219    28           Private  370675     Bachelors               13
# 2340    30           Private  100734     Bachelors               13
# 3308    32           Private  154120       HS-grad                9
# 3705    20           Private  254547       HS-grad                9
# 4228    57           Private  133201       7th-8th                4
# 35890   32           Private   27882  Some-college               10
#
#               marital-status         occupation    relationship  \
# 0              Never-married  Machine-op-inspct       Own-child
# 19        Married-civ-spouse     Prof-specialty         Husband
# 23             Never-married     Prof-specialty   Not-in-family
# 37             Never-married    Priv-house-serv   Not-in-family
# 46        Married-civ-spouse       Craft-repair         Husband
# 74        Married-civ-spouse       Craft-repair         Husband
# 128       Married-civ-spouse       Craft-repair         Husband
# 141            Never-married       Adm-clerical       Own-child
# 220       Married-civ-spouse       Adm-clerical         Husband
# 232            Never-married    Exec-managerial       Unmarried
# 237            Never-married      Other-service       Unmarried
# 296       Married-civ-spouse      Other-service         Husband
# 301            Never-married  Handlers-cleaners  Other-relative
# 309       Married-civ-spouse              Sales         Husband
# 377            Never-married    Exec-managerial       Own-child
# 385       Married-civ-spouse      Other-service         Husband
# 396       Married-civ-spouse    Exec-managerial         Husband
# 398       Married-civ-spouse    Exec-managerial         Husband
# 417       Married-civ-spouse     Prof-specialty  Other-relative
# 473            Never-married     Prof-specialty   Not-in-family
# 498            Never-married  Machine-op-inspct  Other-relative
# 544       Married-civ-spouse    Exec-managerial         Husband
# 586       Married-civ-spouse    Exec-managerial         Husband
# 717    Married-spouse-absent                  ?   Not-in-family
# 794       Married-civ-spouse      Other-service  Other-relative
# 868       Married-civ-spouse     Prof-specialty         Husband
# 890       Married-civ-spouse       Adm-clerical         Husband
# 945       Married-civ-spouse     Prof-specialty         Husband
# 1030           Never-married       Adm-clerical       Own-child
# 1126               Separated       Craft-repair       Unmarried
# 1161      Married-civ-spouse      Other-service         Husband
# 1551      Married-civ-spouse       Adm-clerical         Husband
# 1748      Married-civ-spouse   Transport-moving         Husband
# 1907      Married-civ-spouse    Exec-managerial         Husband
# 1911                 Widowed    Exec-managerial   Not-in-family
# 2047   Married-spouse-absent       Craft-repair   Not-in-family
# 2219           Never-married     Prof-specialty   Not-in-family
# 2340      Married-civ-spouse    Exec-managerial  Other-relative
# 3308      Married-civ-spouse      Other-service         Husband
# 3705           Never-married       Adm-clerical   Not-in-family
# 4228                Divorced       Craft-repair       Unmarried
# 35890          Never-married  Machine-op-inspct  Other-relative
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                   Black    Male             0             0              40
# 19     Asian-Pac-Islander    Male             0             0              45
# 23                  White    Male             0             0              43
# 37                  White    Male             0             0              50
# 46                  White    Male             0             0              40
# 74                  Other    Male             0             0              40
# 128                 White    Male             0             0              60
# 141    Asian-Pac-Islander  Female             0             0              22
# 220    Asian-Pac-Islander    Male             0             0              40
# 232    Asian-Pac-Islander  Female             0             0              50
# 237                 Black  Female             0             0              28
# 296                 White    Male             0             0              32
# 301                 White    Male             0          1721              38
# 309    Asian-Pac-Islander    Male          3103             0              84
# 377    Asian-Pac-Islander  Female             0             0              40
# 385                 White    Male             0             0              35
# 396    Asian-Pac-Islander    Male             0             0              45
# 398    Asian-Pac-Islander    Male             0             0              45
# 417    Asian-Pac-Islander    Male             0             0              40
# 473                 White    Male             0             0              40
# 498    Asian-Pac-Islander    Male             0             0              40
# 544                 White    Male             0             0              45
# 586                 White    Male             0             0              40
# 717    Asian-Pac-Islander  Female             0             0              37
# 794                 White    Male             0             0              40
# 868                 White    Male             0             0              55
# 890                 White    Male             0             0              55
# 945    Asian-Pac-Islander    Male             0             0              40
# 1030                White  Female             0             0              40
# 1126                White    Male          1506             0              40
# 1161                White    Male             0             0              70
# 1551                White    Male             0             0              40
# 1748                Other    Male             0             0              40
# 1907                White    Male             0             0              37
# 1911                White  Female          3325             0              40
# 2047                White    Male             0             0              48
# 2219                White  Female             0          1408              50
# 2340                White  Female             0             0              40
# 3308                White    Male             0             0              40
# 3705                Black  Female             0             0              35
# 4228                White    Male             0          1408              40
# 35890               White  Female             0          2205              40
#
#                    native-country income
# 0                   United-States  <=50K
# 19                              ?   >50K
# 23                           Peru  <=50K
# 37                      Guatemala  <=50K
# 46                         Mexico  <=50K
# 74             Dominican-Republic  <=50K
# 128                       Ireland   >50K
# 141                       Germany  <=50K
# 220                   Philippines  <=50K
# 232                      Thailand  <=50K
# 237                         Haiti  <=50K
# 296                   El-Salvador   >50K
# 301                   Puerto-Rico  <=50K
# 309                       Vietnam  <=50K
# 377                         South  <=50K
# 385                      Columbia  <=50K
# 396                         Japan   >50K
# 398                         India  <=50K
# 417                      Cambodia  <=50K
# 473                        Poland   >50K
# 498                          Laos  <=50K
# 544                       England   >50K
# 586                          Cuba  <=50K
# 717                        Taiwan  <=50K
# 794                         Italy  <=50K
# 868                        Canada  <=50K
# 890                      Portugal   >50K
# 945                         China   >50K
# 1030                    Nicaragua  <=50K
# 1126                     Honduras  <=50K
# 1161                         Iran  <=50K
# 1551                     Scotland  <=50K
# 1748                      Jamaica   >50K
# 1907                      Ecuador   >50K
# 1911                   Yugoslavia  <=50K
# 2047                      Hungary   >50K
# 2219                         Hong  <=50K
# 2340                       Greece   >50K
# 3308              Trinadad&Tobago  <=50K
# 3705   Outlying-US(Guam-USVI-etc)  <=50K
# 4228                       France  <=50K
# 35890          Holand-Netherlands  <=50K

# %%
# Drop duplicate on multiple columns
new_df = df.drop_duplicates(subset=["workclass", "occupation"], keep='first')
new_df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 4       18             ?  103497  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 13836   39   Without-pay  334291       HS-grad                9
# 26110   50  Self-emp-inc  204447  Some-college               10
# 31814   21   Without-pay  232719       HS-grad                9
# 36354   65   Without-pay  172949       HS-grad                9
# 38225   52   Without-pay  198262       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 4           Never-married                  ?      Own-child  White  Female
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 13836  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 26110            Divorced    Protective-serv  Not-in-family  White    Male
# 31814       Never-married       Craft-repair      Own-child  Black    Male
# 36354  Married-civ-spouse   Transport-moving        Husband  White    Male
# 38225  Married-civ-spouse       Adm-clerical           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 13836             0             0              40  United-States  <=50K
# 26110             0             0              40  United-States  <=50K
# 31814             0             0              40  United-States  <=50K
# 36354          2414             0              20  United-States  <=50K
# 38225             0             0              30  United-States  <=50K
#
# [85 rows x 15 columns]

# %% [markdown]
# ### Counting categorical variables
# Counting is a great way to get an overview of your data and to spot curiosities that you might not notice otherwise.

# %%
df["workclass"].value_counts(sort=True)
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df["workclass"].value_counts(normalize=True)
# Out:
# Private             0.694198
# Self-emp-not-inc    0.079071
# Local-gov           0.064207
# ?                   0.057307
# State-gov           0.040559
# Self-emp-inc        0.034704
# Federal-gov         0.029319
# Without-pay         0.000430
# Never-worked        0.000205
# Name: workclass, dtype: float64

# %% [markdown]
# ### Calculations with .groupby()

# %% [markdown]
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Create dataframe
data = {'Company':['GOOG','GOOG','GOOG','MSFT','MSFT','MSFT','FB','FB','FB'],
       'Person':['Sam','Charlie','Ana','Amy','Vanessa','Paul','Carl','Sarah','Sean'],
       'Sales':[200,120,50,340,124,150,243,350,450]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    GOOG      Ana     50
# 3    MSFT      Amy    340
# 4    MSFT  Vanessa    124
# 5    MSFT     Paul    150
# 6      FB     Carl    243
# 7      FB    Sarah    350
# 8      FB     Sean    450

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based off of a column name. For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

# %%
df.groupby('Company')

# %% [markdown]
# You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")

# %% [markdown]
# And then call aggregate methods off the object:

# %%
by_comp['Sales'].mean()
# Out:
# Company
# FB      347.666667
# GOOG    123.333333
# MSFT    204.666667
# Name: Sales, dtype: float64

# %%
df.groupby('Company')['Sales'].mean()
# Out:
# Company
# FB      347.666667
# GOOG    123.333333
# MSFT    204.666667
# Name: Sales, dtype: float64

# %% [markdown]
# More examples of aggregate methods:

# %%
df.groupby('Company')['Sales'].std()
# Out:
# Company
# FB      103.519724
# GOOG     75.055535
# MSFT    117.920877
# Name: Sales, dtype: float64

# %%
df.groupby('Company')['Sales','Person'].min()
# Out:
# /var/folders/2s/6763kr_14zg4wl7bslz22dlh0000gn/T/ipykernel_37301/1072612917.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Company')['Sales','Person'].min()
#          Sales Person
# Company
# FB         243   Carl
# GOOG        50    Ana
# MSFT       124    Amy

# %%
df.groupby('Company')['Sales','Person'].max()
# Out:
# /var/folders/2s/6763kr_14zg4wl7bslz22dlh0000gn/T/ipykernel_37301/3813251763.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Company')['Sales','Person'].max()
#          Sales   Person
# Company
# FB         450     Sean
# GOOG       200      Sam
# MSFT       340  Vanessa

# %%
df.loc[df.groupby('Company')['Sales'].idxmin()]
# Out:
#   Company   Person  Sales
# 6      FB     Carl    243
# 2    GOOG      Ana     50
# 4    MSFT  Vanessa    124

# %%
df.groupby('Company')['Sales','Person'].count()
# Out:
# /var/folders/2s/6763kr_14zg4wl7bslz22dlh0000gn/T/ipykernel_37301/1332486916.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Company')['Sales','Person'].count()
#          Sales  Person
# Company
# FB           3       3
# GOOG         3       3
# MSFT         3       3

# %%
df.groupby('Company')['Sales'].describe()
# Out:
#          count        mean         std    min    25%    50%    75%    max
# Company
# FB         3.0  347.666667  103.519724  243.0  296.5  350.0  400.0  450.0
# GOOG       3.0  123.333333   75.055535   50.0   85.0  120.0  160.0  200.0
# MSFT       3.0  204.666667  117.920877  124.0  137.0  150.0  245.0  340.0

# %%
df.groupby('Company')['Sales'].describe().transpose()
# Out:
# Company          FB        GOOG        MSFT
# count      3.000000    3.000000    3.000000
# mean     347.666667  123.333333  204.666667
# std      103.519724   75.055535  117.920877
# min      243.000000   50.000000  124.000000
# 25%      296.500000   85.000000  137.000000
# 50%      350.000000  120.000000  150.000000
# 75%      400.000000  160.000000  245.000000
# max      450.000000  200.000000  340.000000

# %%
df.groupby('Company')['Sales'].describe().transpose()['GOOG']
# Out:
# count      3.000000
# mean     123.333333
# std       75.055535
# min       50.000000
# 25%       85.000000
# 50%      120.000000
# 75%      160.000000
# max      200.000000
# Name: GOOG, dtype: float64

# %%
### Multiple grouped statistics
df.groupby('Company').agg([min,max])
# Out:
#         Person          Sales
#            min      max   min  max
# Company
# FB        Carl     Sean   243  450
# GOOG       Ana      Sam    50  200
# MSFT       Amy  Vanessa   124  340

# %%
df.groupby('Company').agg(
    {
        'Person':['min'],
     'Sales':['min', 'max']
    })
# Out:
#         Person Sales
#            min   min  max
# Company
# FB        Carl   243  450
# GOOG       Ana    50  200
# MSFT       Amy   124  340

# %%
df.groupby(['Company','Person'])['Sales'].mean()
# Out:
# Company  Person
# FB       Carl       243
#          Sarah      350
#          Sean       450
# GOOG     Ana         50
#          Charlie    120
#          Sam        200
# MSFT     Amy        340
#          Paul       150
#          Vanessa    124
# Name: Sales, dtype: int64

# %%
df.groupby(['Company'])['Person','Sales'].min()
# Out:
#         Person  Sales
# Company
# FB        Carl    243
# GOOG       Ana     50
# MSFT       Amy    124

# %% [markdown]
# ### Pivot Tables

# %%
# df.groupby('Company')['Sales'].mean()

df.pivot_table(values="Sales", index="Company", aggfunc='mean')
# Out:
#               Sales
# Company
# FB       347.666667
# GOOG     123.333333
# MSFT     204.666667

# %%
import numpy as np
df.pivot_table(values="Sales", index="Company", aggfunc='min')
# Out:
#          Sales
# Company
# FB         243
# GOOG        50
# MSFT       124

# %%
df.pivot_table(values="Sales", index="Company", aggfunc=[np.mean,np.median])
# Out:
#                mean median
#               Sales  Sales
# Company
# FB       347.666667    350
# GOOG     123.333333    120
# MSFT     204.666667    150

# %%
# df.groupby(['Company','Person'])['Sales'].mean()

df.pivot_table(values="Sales", index="Company", columns="Person")
# Out:
# Person     Amy   Ana   Carl  Charlie   Paul    Sam  Sarah   Sean  Vanessa
# Company
# FB         NaN   NaN  243.0      NaN    NaN    NaN  350.0  450.0      NaN
# GOOG       NaN  50.0    NaN    120.0    NaN  200.0    NaN    NaN      NaN
# MSFT     340.0   NaN    NaN      NaN  150.0    NaN    NaN    NaN    124.0

# %%
df.pivot_table(values="Sales", index="Company", columns="Person", fill_value=0)
# Out:
# Person   Amy  Ana  Carl  Charlie  Paul  Sam  Sarah  Sean  Vanessa
# Company
# FB         0    0   243        0     0    0    350   450        0
# GOOG       0   50     0      120     0  200      0     0        0
# MSFT     340    0     0        0   150    0      0     0      124

# %%
df.pivot_table(values="Sales", index="Company", columns="Person", fill_value=0, margins=True)
# Out:
# Person   Amy  Ana  Carl  Charlie  Paul  Sam  Sarah  Sean  Vanessa         All
# Company
# FB         0    0   243        0     0    0    350   450        0  347.666667
# GOOG       0   50     0      120     0  200      0     0        0  123.333333
# MSFT     340    0     0        0   150    0      0     0      124  204.666667
# All      340   50   243      120   150  200    350   450      124  225.000000

# %% [markdown]
# # Great Job!
